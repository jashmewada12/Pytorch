# %%
# %cd "C:\Free code camp\fcc ml\going_modular_05\going_modular"
# Out:
# C:\Free code camp\fcc ml\going_modular_05\going_modular

# %%
# %run train.py -h
# Out:
# usage: train.py [-h] [--num_epochs NUM_EPOCHS] [--batch_size BATCH_SIZE]
#                 [--hidden_units HIDDEN_UNITS] [--learning_rate LEARNING_RATE]
#                 [--train_transform TRAIN_TRANSFORM] [--pred_img PRED_IMG]
#
# Train a TinyVGG model with custom hyperparameters.
#
# options:
#   -h, --help            show this help message and exit
#   --num_epochs NUM_EPOCHS
#                         Number of epochs to train for
#   --batch_size BATCH_SIZE
#                         Number of samples per batch
#   --hidden_units HIDDEN_UNITS
#                         Number of hidden units in the model
#   --learning_rate LEARNING_RATE
#                         Learning rate for the optimizer
#   --train_transform TRAIN_TRANSFORM
#                         Type of transforms to apply on training images
#   --pred_img PRED_IMG   path of the image you want to make predictions on

# %%
# %run train.py --num_epochs 50 --batch_size 32 --hidden_units 20 --learning_rate 0.001
# Out:
# [INFO]
# epochs : 50
# batch size : 32
# hidden units : 20
# learning rate : 0.001
# Transforms : Compose(
#     Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=True)
#     TrivialAugmentWide(num_magnitude_bins=20, interpolation=InterpolationMode.NEAREST, fill=None)
#     ToTensor()
# )
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1112 | train_acc: 0.3242 | test_loss: 1.1088 | test_acc: 0.2708
# Epoch: 2 | train_loss: 1.1055 | train_acc: 0.2383 | test_loss: 1.0737 | test_acc: 0.5729
# Epoch: 3 | train_loss: 1.0891 | train_acc: 0.5039 | test_loss: 1.0817 | test_acc: 0.4830
# Epoch: 4 | train_loss: 1.0680 | train_acc: 0.4141 | test_loss: 1.0498 | test_acc: 0.3627
# Epoch: 5 | train_loss: 1.0241 | train_acc: 0.5195 | test_loss: 1.1230 | test_acc: 0.2907
# Epoch: 6 | train_loss: 0.9652 | train_acc: 0.5547 | test_loss: 1.1281 | test_acc: 0.3333
# Epoch: 7 | train_loss: 1.0362 | train_acc: 0.4141 | test_loss: 0.9607 | test_acc: 0.5341
# Epoch: 8 | train_loss: 0.9991 | train_acc: 0.5703 | test_loss: 0.9219 | test_acc: 0.5938
# Epoch: 9 | train_loss: 0.9512 | train_acc: 0.5430 | test_loss: 1.0083 | test_acc: 0.4138
# Epoch: 10 | train_loss: 0.9374 | train_acc: 0.5625 | test_loss: 1.0643 | test_acc: 0.3314
# Epoch: 11 | train_loss: 1.0198 | train_acc: 0.4219 | test_loss: 0.9889 | test_acc: 0.3920
# Epoch: 12 | train_loss: 0.9354 | train_acc: 0.6328 | test_loss: 0.9727 | test_acc: 0.4337
# Epoch: 13 | train_loss: 0.9131 | train_acc: 0.6367 | test_loss: 0.9011 | test_acc: 0.5653
# Epoch: 38 | train_loss: 0.7655 | train_acc: 0.6914 | test_loss: 1.0169 | test_acc: 0.5360
# Epoch: 39 | train_loss: 0.8861 | train_acc: 0.5195 | test_loss: 1.0424 | test_acc: 0.4252
# Epoch: 40 | train_loss: 0.9227 | train_acc: 0.5508 | test_loss: 0.9462 | test_acc: 0.5975
# Epoch: 41 | train_loss: 0.8919 | train_acc: 0.5547 | test_loss: 0.9199 | test_acc: 0.5975
# Epoch: 42 | train_loss: 0.8239 | train_acc: 0.6641 | test_loss: 1.0382 | test_acc: 0.4138
# Epoch: 43 | train_loss: 0.9258 | train_acc: 0.4922 | test_loss: 1.1097 | test_acc: 0.3835
# Epoch: 44 | train_loss: 0.8117 | train_acc: 0.6914 | test_loss: 0.9818 | test_acc: 0.4242
# Epoch: 45 | train_loss: 0.8378 | train_acc: 0.6875 | test_loss: 1.0083 | test_acc: 0.5265
# Epoch: 46 | train_loss: 0.7688 | train_acc: 0.7305 | test_loss: 0.9225 | test_acc: 0.5246
# Epoch: 47 | train_loss: 0.7354 | train_acc: 0.6797 | test_loss: 0.9323 | test_acc: 0.5862
# Epoch: 48 | train_loss: 0.7774 | train_acc: 0.5938 | test_loss: 0.9711 | test_acc: 0.4953
# Epoch: 49 | train_loss: 0.6674 | train_acc: 0.7500 | test_loss: 1.0207 | test_acc: 0.4555
# Epoch: 50 | train_loss: 0.7052 | train_acc: 0.7031 | test_loss: 0.9946 | test_acc: 0.5057
# [INFO] Saving model to: models\05_going_modular_script_mode_tinyvgg_model_v1.pth

# %%
# %run conf_mat.py -h
# Out:
# usage: conf_mat.py [-h] --model_path MODEL_PATH [--batch_size BATCH_SIZE]
#                    [--hidden_units HIDDEN_UNITS]
#
# Plots a confusion matrix for a saved model
#
# options:
#   -h, --help            show this help message and exit
#   --model_path MODEL_PATH
#                         Path to the saved model .pth file
#   --batch_size BATCH_SIZE
#                         Batch size for testing data
#   --hidden_units HIDDEN_UNITS
#                         Hidden units used when training the model

# %%
# %run conf_mat.py --model_path "C:\Free code camp\fcc ml\going_modular_05\going_modular\models\05_going_modular_script_mode_tinyvgg_model_v1.pth" --batch_size 32 --hidden_units 20
# Out:
# [INFO] Loading testing data..
# [INFO] Instantiating TinyVGG model with 20 hidden units...
# [INFO] Loading weights from: C:\Free code camp\fcc ml\going_modular_05\going_modular\models\05_going_modular_script_mode_tinyvgg_model_v1.pth
# [INFO] Running inference on test dataset...
# C:\Free code camp\fcc ml\going_modular_05\going_modular\conf_mat.py:50: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(args.model_path, map_location=device))
# Making predictions:   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] Generating Confusion Matrix plot...
